# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Download the data and load it to Pandas.
#
# You can find them [here](https://drive.google.com/file/d/1NY6cmF9Shjw-dD7BD6bNmfcIVz-kQcFR/view?usp=sharing).

# %%
titles = pd.read_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast = pd.read_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### Define a year as a "Superman year" whose films feature more Superman characters than Batman. How many years in film history have been Superman years?

# %%
superman = cast[cast['title'].str.contains('Superman')].groupby('year')['character'].count().reset_index(name = 'superman')

# %%
batman = cast[cast['title'].str.contains('Batman')].groupby('year')['character'].count().reset_index(name = 'batman')

# %%
super_bat_man = pd.merge(superman,batman,on='year',how = 'left')

# %%
# super_bat_man['superman_years'] = np.where(super_bat_man['superman'] > super_bat_man['batman'], 'superman_year')\
#                                     .otherwise(None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-bb2c594458af> in <module>
# ----> 1 super_bat_man['superman_years'] = np.where(super_bat_man['superman'] > super_bat_man['batman'], 'superman_year')\
#       2                                     .otherwise(None)
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given

# %%
super_bat_man['Superman_year'] = None
super_bat_man.loc[super_bat_man['superman']>super_bat_man['batman'], 'Superman_year'] = 'Superman_year'
super_bat_man.loc[super_bat_man['batman'].isnull(), 'Superman_year'] = 'Superman_year'

# %%
super_bat_man[super_bat_man['Superman_year'].notnull()]['year'].count()
# Out:
# 15

# %% [markdown]
# ### How many years have been "Batman years", with more Batman characters than Superman characters?

# %%
bat_super_man = pd.merge(superman,batman,on='year',how = 'right')

# %%
bat_super_man['batman_year'] = None
bat_super_man.loc[bat_super_man['superman']<bat_super_man['batman'], 'batman_year'] = 'batman_year'
bat_super_man.loc[bat_super_man['superman'].isnull(), 'batman_year'] = 'batman_year'

# %%
bat_super_man[bat_super_man['batman_year'].notnull()]['year'].count()
# Out:
# 17

# %% [markdown]
# ### Count the number of actor roles each year and the number of actress roles each year over the history of film.

# %%
counts = cast.groupby(['year','type'])['name'].count().reset_index(name='cnt')
counts
# Out:
#      year     type  cnt
# 0    1894    actor    2
# 1    1894  actress    1
# 2    1900    actor    2
# 3    1905    actor    1
# 4    1906    actor   14
# ..    ...      ...  ...
# 235  2022  actress   11
# 236  2023    actor    6
# 237  2023  actress    5
# 238  2025    actor    2
# 239  2026    actor    1
#
# [240 rows x 3 columns]

# %% [markdown]
# ### Find the difference between the number of actor roles each year and the number of actress roles each year over the history of film.

# %%
diff = pd.pivot_table(counts, values='cnt',columns=['type'],index = ['year'])

diff['actor_clean'] = np.select(
    [ diff['actor'].isnull() ], 
    [ 0 ], 
    default=diff['actor'])

diff['actress_clean'] = np.select(
    [ diff['actress'].isnull() ], 
    [ 0 ], 
    default=diff['actress'])

diff['difference'] = diff['actor_clean'] - diff['actress_clean']

# %%
diff
# Out:
# type  actor  actress  actor_clean  actress_clean  difference
# year
# 1894    2.0      1.0          2.0            1.0         1.0
# 1900    2.0      NaN          2.0            0.0         2.0
# 1905    1.0      NaN          1.0            0.0         1.0
# 1906   14.0      3.0         14.0            3.0        11.0
# 1907    5.0      NaN          5.0            0.0         5.0
# ...     ...      ...          ...            ...         ...
# 2021    9.0      4.0          9.0            4.0         5.0
# 2022   18.0     11.0         18.0           11.0         7.0
# 2023    6.0      5.0          6.0            5.0         1.0
# 2025    2.0      NaN          2.0            0.0         2.0
# 2026    1.0      NaN          1.0            0.0         1.0
#
# [123 rows x 5 columns]

# %% [markdown]
# ### What is the fraction of roles that have been 'actor' roles each year in the history of film.

# %%
diff['total'] = diff['actor_clean'] + diff['actress_clean']

# %%
diff['actor_perc'] = diff['actor_clean']/diff['total']

# %%
diff
# Out:
# type  actor  actress  actor_clean  actress_clean  difference  total  \
# year
# 1894    2.0      1.0          2.0            1.0         1.0    3.0
# 1900    2.0      NaN          2.0            0.0         2.0    2.0
# 1905    1.0      NaN          1.0            0.0         1.0    1.0
# 1906   14.0      3.0         14.0            3.0        11.0   17.0
# 1907    5.0      NaN          5.0            0.0         5.0    5.0
# ...     ...      ...          ...            ...         ...    ...
# 2021    9.0      4.0          9.0            4.0         5.0   13.0
# 2022   18.0     11.0         18.0           11.0         7.0   29.0
# 2023    6.0      5.0          6.0            5.0         1.0   11.0
# 2025    2.0      NaN          2.0            0.0         2.0    2.0
# 2026    1.0      NaN          1.0            0.0         1.0    1.0
#
# type  actor_perc
# year
# 1894    0.666667
# 1900    1.000000
# 1905    1.000000
# 1906    0.823529
# 1907    1.000000
# ...          ...
# 2021    0.692308
# 2022    0.620690
# 2023    0.545455
# 2025    1.000000
# 2026    1.000000
#
# [123 rows x 7 columns]

# %% [markdown]
# ### What is the fraction of supporting (n=2) roles that have been 'actor' roles each year in the history of film.

# %%
counts_2 = cast[cast['n']==2].groupby(['year','type'])['name'].count().reset_index(name='cnt')

# %%
diff_2 = pd.pivot_table(counts_2, values='cnt',columns=['type'],index = ['year'])

diff_2['actor_clean'] = np.select(
    [ diff_2['actor'].isnull() ], 
    [ 0 ], 
    default=diff_2['actor'])

diff_2['actress_clean'] = np.select(
    [ diff_2['actress'].isnull() ], 
    [ 0 ], 
    default=diff_2['actress'])

diff_2['difference'] = diff_2['actor_clean'] - diff_2['actress_clean']

# %%
diff_2['total'] = diff_2['actor_clean'] + diff_2['actress_clean']

# %%
diff_2['actor_perc'] = diff_2['actor_clean']/diff_2['total']

# %%
diff_2
# Out:
# type   actor  actress  actor_clean  actress_clean  difference   total  \
# year
# 1906     2.0      1.0          2.0            1.0         1.0     3.0
# 1907     1.0      NaN          1.0            0.0         1.0     1.0
# 1908     2.0      NaN          2.0            0.0         2.0     2.0
# 1910     2.0      2.0          2.0            2.0         0.0     4.0
# 1911    14.0      5.0         14.0            5.0         9.0    19.0
# ...      ...      ...          ...            ...         ...     ...
# 2016  2337.0   1823.0       2337.0         1823.0       514.0  4160.0
# 2017   883.0    643.0        883.0          643.0       240.0  1526.0
# 2018    41.0     30.0         41.0           30.0        11.0    71.0
# 2019     7.0      2.0          7.0            2.0         5.0     9.0
# 2020     1.0      2.0          1.0            2.0        -1.0     3.0
#
# type  actor_perc
# year
# 1906    0.666667
# 1907    1.000000
# 1908    1.000000
# 1910    0.500000
# 1911    0.736842
# ...          ...
# 2016    0.561779
# 2017    0.578637
# 2018    0.577465
# 2019    0.777778
# 2020    0.333333
#
# [114 rows x 7 columns]

# %%
cast[(cast['year']== 1906)].sort_values('n')
# Out:
#                                       title  year                  name  \
# 771162   The Joe Gans-Battling Nelson Fight  1906              Joe Gans
# 1234324                       Lika mot lika  1906          Knut Lambert
# 3492076         The Story of the Kelly Gang  1906        Elizabeth Tait
# 1597101  The Joe Gans-Battling Nelson Fight  1906       Battling Nelson
# 2160407         The Story of the Kelly Gang  1906             John Tait
# 3041085                       Lika mot lika  1906       Helfrid Lambert
# 3627826                       Lika mot lika  1906        Tollie Zellman
# 325926          The Story of the Kelly Gang  1906  Norman (II) Campbell
# 471862          The Story of the Kelly Gang  1906            Will Coyne
# 478233          The Story of the Kelly Gang  1906            Sam Crewes
# 656289          The Story of the Kelly Gang  1906       Jack (II) Ennis
# 726671          The Story of the Kelly Gang  1906      John (III) Forde
# 1399935         The Story of the Kelly Gang  1906          Mr. Marshall
# 1454514         The Story of the Kelly Gang  1906          Mr. McKenzie
# 1502763         The Story of the Kelly Gang  1906      Frank (VI) Mills
# 2160396         The Story of the Kelly Gang  1906             E.J. Tait
# 2160397         The Story of the Kelly Gang  1906            Frank Tait
#
#             type             character    n
# 771162     actor               Himself  1.0
# 1234324    actor             Coq-H?ron  1.0
# 3492076  actress            Kate Kelly  1.0
# 1597101    actor               Himself  2.0
# 2160407    actor         School Master  2.0
# 3041085  actress               Suzanne  2.0
# 3627826  actress  Clara, kammarjungfru  3.0
# 325926     actor            Steve Hart  NaN
# 471862     actor             Joe Byrne  NaN
# 478233     actor             Dan Kelly  NaN
# 656289     actor            Steve Hart  NaN
# 726671     actor             Dan Kelly  NaN
# 1399935    actor             Dan Kelly  NaN
# 1454514    actor            Steve Hart  NaN
# 1502763    actor             Ned Kelly  NaN
# 2160396    actor                 Extra  NaN
# 2160397    actor                 Extra  NaN
