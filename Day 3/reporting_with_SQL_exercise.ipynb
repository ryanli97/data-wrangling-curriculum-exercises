# %% [markdown]
# # SQL in Python Exercise

# %% [markdown]
# In this exercises we will be using Jupyter and Python as our IDE for SQL. We can download the northwind database from [here](https://drive.google.com/file/d/1HCfNF5BsYUrQhhr-vnO_LFgs5THJUAh_/view?usp=sharing). Before we go to the actual tasks we will remember how we can connect to existing databases.

# %%
import pandas as pd
import sqlite3

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn

# %%
# if northwind is in the same working directory
con = create_connection("northwind (2).db")

# %% [markdown]
# > #### Warning
# > in case the file is somewhere else it will still work but create new, empty database.

# %% [markdown]
# ### Get all table names
#
# **1. classic Python approach**

# %%
cursor = con.cursor()

res = cursor.execute("SELECT type, name FROM sqlite_master WHERE type='table'").fetchall()
all_tables = pd.DataFrame(res)
all_tables.columns = ["type","name"]
all_tables
# Out:
#     type                 name
# 0  table            Employees
# 1  table           Categories
# 2  table            Customers
# 3  table             Shippers
# 4  table            Suppliers
# 5  table               Orders
# 6  table             Products
# 7  table        Order Details
# 8  table          Territories
# 9  table  EmployeeTerritories

# %% [markdown]
# **2. with pandas**

# %%
all_tables = pd.read_sql("SELECT type, name FROM sqlite_master WHERE type='table'", con)
all_tables
# Out:
#     type                 name
# 0  table            Employees
# 1  table           Categories
# 2  table            Customers
# 3  table             Shippers
# 4  table            Suppliers
# 5  table               Orders
# 6  table             Products
# 7  table        Order Details
# 8  table          Territories
# 9  table  EmployeeTerritories

# %% [markdown]
# Using **read_sql** method from Pandas we can easily pull any SQL query into table format in Python.

# %%
orders = pd.read_sql("SELECT * FROM orders", con)
orders.ShippedDate.value_counts()
# Out:
# 1998-04-10    8
# 1998-03-18    7
# 1998-01-23    6
# 1998-04-08    6
# 1998-04-24    6
#              ..
# 1997-12-23    1
# 1997-03-26    1
# 1997-05-14    1
# 1998-04-09    1
# 1997-06-12    1
# Name: ShippedDate, Length: 387, dtype: int64

# %% [markdown]
# ### Task I:
# Write a query to get Product name and quantity/unit.

# %%
product_name_quantity = pd.read_sql(
    """SELECT ProductID, ProductName,sum(UnitsInStock) as UnitsInStock,
              sum(UnitsOnOrder) as UnitsOnOrder
              FROM products
    group by ProductName
    """, con)

product_name_quantity
# Out:
#     ProductID                      ProductName  UnitsInStock  UnitsOnOrder
# 0          17                     Alice Mutton             0             0
# 1           3                    Aniseed Syrup            13            70
# 2          40                 Boston Crab Meat           123             0
# 3          60                Camembert Pierrot            19             0
# 4          18                 Carnarvon Tigers            42             0
# ..        ...                              ...           ...           ...
# 72          7  Uncle Bob's Organic Dried Pears            15             0
# 73         50                 Valkoinen suklaa            65             0
# 74         63                     Vegie-spread            24             0
# 75         64        Wimmers gute Semmelknödel            22            80
# 76         47                    Zaanse koeken            36             0
#
# [77 rows x 4 columns]

# %% [markdown]
# ### Task II:
# Write a query to get the most expensive and least expensive Product (name and unit price)

# %%
# pd.read_sql(
#     """SELECT *
#               FROM products limit 2
#     """, con)

print(pd.read_sql(
    """SELECT ProductName, min(UnitPrice) as min_unitprice
              FROM products
    """, con))

print(pd.read_sql(
    """SELECT ProductName, max(UnitPrice) as max_unitprice
              FROM products
    """, con))
# Out:
#   ProductName  min_unitprice
# 0     Geitost            2.5
#      ProductName  max_unitprice
# 0  Côte de Blaye          263.5

# %% [markdown]
# ### Task III:
# Write a query to count current and discontinued products.

# %%
pd.read_sql(
    """SELECT discontinued, count(*)
              FROM products
              group by discontinued
    """, con)
# Out:
#    Discontinued  count(*)
# 0             0        69
# 1             1         8

# %% [markdown]
# ### Task IV:
# Select all product names and their category names.

# %%
pd.read_sql(
    """SELECT distinct productname,categoryname
              FROM products as a 
        left join Categories as b
        on a.categoryid = b.categoryid
              
    """, con)
# Out:
#                         ProductName    CategoryName
# 0                      Alice Mutton    Meat/Poultry
# 1                     Aniseed Syrup      Condiments
# 2                  Boston Crab Meat         Seafood
# 3                 Camembert Pierrot  Dairy Products
# 4                  Carnarvon Tigers         Seafood
# ..                              ...             ...
# 72  Uncle Bob's Organic Dried Pears         Produce
# 73                 Valkoinen suklaa     Confections
# 74                     Vegie-spread      Condiments
# 75        Wimmers gute Semmelknödel  Grains/Cereals
# 76                    Zaanse koeken     Confections
#
# [77 rows x 2 columns]

# %%
pd.read_sql(
    """SELECT *
              FROM Categories
              limit 3
    """, con)
# Out:
#    CategoryID CategoryName                                        Description  \
# 0           1    Beverages        Soft drinks, coffees, teas, beers, and ales
# 1           2   Condiments  Sweet and savory sauces, relishes, spreads, an...
# 2           3  Confections                Desserts, candies, and sweet breads
#
#   Picture
# 0    None
# 1    None
# 2    None

# %% [markdown]
# ### Task V:
# Select all product names, unit price and the supplier region that don't have suppliers from USA region. (26 rows)

# %%
pd.read_sql(
    """SELECT distinct ProductName,UnitPrice,Region,Country
              FROM products as a
        left join suppliers as b
        on a.supplierid = b.supplierid
        where country not like ('USA')

    """, con)
# Out:
#                   ProductName  UnitPrice    Region      Country
# 0                Alice Mutton      39.00  Victoria    Australia
# 1               Aniseed Syrup      10.00      None           UK
# 2           Camembert Pierrot      34.00      None       France
# 3            Carnarvon Tigers      62.50  Victoria    Australia
# 4                        Chai      18.00      None           UK
# ..                        ...        ...       ...          ...
# 60                   Tunnbröd       9.00      None       Sweden
# 61           Valkoinen suklaa      16.25      None      Finland
# 62               Vegie-spread      43.90  Victoria    Australia
# 63  Wimmers gute Semmelknödel      33.25      None      Germany
# 64              Zaanse koeken       9.50      None  Netherlands
#
# [65 rows x 4 columns]

# %%
pd.read_sql(
    """SELECT *
              FROM suppliers
              limit 3
    """, con)
# Out:
#    SupplierID                 CompanyName       ContactName  \
# 0           1              Exotic Liquids  Charlotte Cooper
# 1           2  New Orleans Cajun Delights     Shelley Burke
# 2           3   Grandma Kelly's Homestead     Regina Murphy
#
#            ContactTitle         Address         City Region PostalCode  \
# 0    Purchasing Manager  49 Gilbert St.       London   None    EC1 4SD
# 1   Order Administrator  P.O. Box 78934  New Orleans     LA      70117
# 2  Sales Representative  707 Oxford Rd.    Ann Arbor     MI      48104
#
#   Country           Phone             Fax     HomePage
# 0      UK  (171) 555-2222            None         None
# 1     USA  (100) 555-4822            None  #CAJUN.HTM#
# 2     USA  (313) 555-5735  (313) 555-3349         None

# %%
pd.read_sql(
    """SELECT *
              FROM products
              limit 3
    """, con)
# Out:
#    ProductID    ProductName  SupplierID  CategoryID      QuantityPerUnit  \
# 0          1           Chai           1           1   10 boxes x 20 bags
# 1          2          Chang           1           1   24 - 12 oz bottles
# 2          3  Aniseed Syrup           1           2  12 - 550 ml bottles
#
#    UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 0       18.0            39             0            10             0
# 1       19.0            17            40            25             0
# 2       10.0            13            70            25             0

# %% [markdown]
# ### Task VI:
# Create report which shows a number of orders for each month.

# %%
pd.read_sql(
    """SELECT strftime('%m', OrderDate) as month,count(*) as cnt
              FROM orders
              group by strftime('%m', OrderDate)
    """, con)
# Out:
#    month  cnt
# 0     01   88
# 1     02   83
# 2     03  103
# 3     04  105
# 4     05   46
# 5     06   30
# 6     07   55
# 7     08   58
# 8     09   60
# 9     10   64
# 10    11   59
# 11    12   79

# %% [markdown]
# ### Task VII:
# Create report which shows total quantity of orders sold for each order.(830 rows)

# %%
pd.read_sql(
    """SELECT a.OrderID, sum(quantity) as total_ordered
              FROM orders as a 
              left join `Order Details` as b
              on a.OrderID = b.OrderID
              group by a.OrderID
    """, con)
# Out:
#      OrderID  total_ordered
# 0      10248             27
# 1      10249             49
# 2      10250             60
# 3      10251             41
# 4      10252            105
# ..       ...            ...
# 825    11073             30
# 826    11074             14
# 827    11075             42
# 828    11076             50
# 829    11077             72
#
# [830 rows x 2 columns]

# %%
# Out:
#      OrderID CustomerID  EmployeeID   OrderDate RequiredDate ShippedDate  \
# 0      10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 1      10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 2      10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 3      10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
# 4      10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
# ...      ...        ...         ...         ...          ...         ...
# 2150   11077      RATTC           1  1998-05-06   1998-06-03        None
# 2151   11077      RATTC           1  1998-05-06   1998-06-03        None
# 2152   11077      RATTC           1  1998-05-06   1998-06-03        None
# 2153   11077      RATTC           1  1998-05-06   1998-06-03        None
# 2154   11077      RATTC           1  1998-05-06   1998-06-03        None
#
#       ShipVia  Freight                    ShipName         ShipAddress  ...  \
# 0           3    32.38   Vins et alcools Chevalier  59 rue de l'Abbaye  ...
# 1           3    32.38   Vins et alcools Chevalier  59 rue de l'Abbaye  ...
# 2           3    32.38   Vins et alcools Chevalier  59 rue de l'Abbaye  ...
# 3           1    11.61          Toms Spezialitäten       Luisenstr. 48  ...
# 4           1    11.61          Toms Spezialitäten       Luisenstr. 48  ...
# ...       ...      ...                         ...                 ...  ...
# 2150        2     8.53  Rattlesnake Canyon Grocery     2817 Milton Dr.  ...
# 2151        2     8.53  Rattlesnake Canyon Grocery     2817 Milton Dr.  ...
# 2152        2     8.53  Rattlesnake Canyon Grocery     2817 Milton Dr.  ...
# 2153        2     8.53  Rattlesnake Canyon Grocery     2817 Milton Dr.  ...
# 2154        2     8.53  Rattlesnake Canyon Grocery     2817 Milton Dr.  ...
#
#      ShipRegion ShipPostalCode ShipCountry OrderID  ProductID  UnitPrice  \
# 0          None          51100      France   10248         11      14.00
# 1          None          51100      France   10248         42       9.80
# 2          None          51100      France   10248         72      34.80
# 3          None          44087     Germany   10249         14      18.60
# 4          None          44087     Germany   10249         51      42.40
# ...         ...            ...         ...     ...        ...        ...
# 2150         NM          87110         USA   11077         64      33.25
# 2151         NM          87110         USA   11077         66      17.00
# 2152         NM          87110         USA   11077         73      15.00
# 2153         NM          87110         USA   11077         75       7.75
# 2154         NM          87110         USA   11077         77      13.00
#
#       Quantity  Discount    total  dow
# 0           12      0.00   168.00    4
# 1           10      0.00    98.00    4
# 2            5      0.00   174.00    4
# 3            9      0.00   167.40    5
# 4           40      0.00  1696.00    5
# ...        ...       ...      ...  ...
# 2150         2      0.03    66.44    3
# 2151         1      0.00    17.00    3
# 2152         2      0.01    29.98    3
# 2153         4      0.00    31.00    3
# 2154         2      0.00    26.00    3
#
# [2155 rows x 21 columns]

# %% [markdown]
# ### Task VIII:
# Create report which shows how many years each employee works in the company. (9 rows)

# %%
pd.read_sql(
    """SELECT *
              FROM Employees
    """, con)
# Out:
# Empty DataFrame
# Columns: [EmployeeID, LastName, FirstName, Title, TitleOfCourtesy, BirthDate, HireDate, Address, City, Region, PostalCode, Country, HomePhone, Extension, Photo, Notes, ReportsTo, PhotoPath]
# Index: []

# %% [markdown]
# ### Task IX:
# Which day of the week is the best for orders?

# %%
pd.read_sql(
    """SELECT strftime('%w', OrderDate) as dow, count(*) as cnt
              FROM orders
              group by dow
              order by cnt desc
              
    """, con)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# OperationalError: near "group": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-116-0cbe989e51ea> in <module>
# ----> 1 pd.read_sql(
#       2     """SELECT strftime('%w', OrderDate) as dow, count(*) as cnt
#       3               FROM orders
#       4               where orderid > 100
#       5               limit(2)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     404
#     405     if isinstance(pandas_sql, SQLiteDatabase):
# --> 406         return pandas_sql.read_query(
#     407             sql,
#     408             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1631
#    1632         args = _convert_params(sql, params)
# -> 1633         cursor = self.execute(*args)
#    1634         columns = [col_desc[0] for col_desc in cursor.description]
#    1635
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1596
#    1597             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1598             raise ex from exc
#    1599
#    1600     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT strftime('%w', OrderDate) as dow, count(*) as cnt
#               FROM orders
#               where orderid > 100
#               limit(2)
#               group by dow
#               order by cnt desc
#
#     ': near "group": syntax error

# %%
pd.read_sql(
    """SELECT  strftime('%w', OrderDate) as dow, sum(((unitprice - discount)*Quantity)) as total
              FROM orders as a 
              left join `Order Details` as b
              on a.OrderID = b.OrderID
              group by dow
              order by total desc
              
    """, con)
# Out:
#   dow      total
# 0   5  283765.44
# 1   1  274653.05
# 2   2  271543.77
# 3   3  265739.51
# 4   4  255434.86
